# %% [markdown]
# # 1. Задание 1
# Выберите верное определение.
# Транзакция — это:
#
# Выберите один вариант из списка
#
#
# *   последовательность операций, каждая из которых фиксируется независимо от других.
#
# *   одна операция в рамках серии последовательных SQL-запросов.
# *   **последовательность операций, которые нужно выполнить как единое целое.**
#
#
# *   последовательность операций, которые можно выполнять в любом порядке.
#
#
#
# *   независимый SQL-запрос, который выполняется отдельно от других запросов.
#
#
#
# # 2. Задание 2
# Выберите правильную структуру запроса, который зафиксирует транзакцию:
#
# Выберите один вариант из списка
#
# ```
# START TRANSACTION;
#     UPDATE ...;
#     SELECT ...;
#     INSERT ...;
# FIX;
# ```
#
# ```
# START TRANSACTION;
#     UPDATE ...;
#     SELECT ...;
#     INSERT ...;
# END TRANSACTION;
# ```
#
# ```
# START TRANSACTION;
#     UPDATE ...;
#     SELECT ...;
#     INSERT ...;
# SAVE TRANSACTION;
# ```
#
# ```
# START TRANSACTION;
#     UPDATE ...;
#     SELECT ...;
#     INSERT ...;
# ROLLBACK;
# ```
#
# **START TRANSACTION;
#     UPDATE ...;
#     SELECT ...;
#     INSERT ...;
# COMMIT;**
#
#
#
# # 3. Задание 3
# Выберите правильную структуру запроса, который откатит транзакцию:
# ```
# START TRANSACTION;
#     UPDATE ...;
#     SELECT ...;
#     INSERT ...;
# END TRANSACTION;
# ```
#
# ```
# START TRANSACTION;
#     UPDATE ...;
#     SELECT ...;
#     INSERT ...;
# CANCEL TRANSACTION;
# ```
#
# ```
# START TRANSACTION;
#     UPDATE ...;
#     SELECT ...;
#     INSERT ...;
# COMMIT;
# ```
#
# **START TRANSACTION;
#     UPDATE ...;
#     SELECT ...;
#     INSERT ...;
# ROLLBACK;**
#
# # 4. Задание 4
# Выберите правильное определение атомарности.
#
# Выберите один вариант из списка
#
#
#
#
# *   Атомарность гарантирует, что в рамках транзакции, каждый отдельный запрос будет выполнен без ошибок.
# *   **Атомарность гарантирует, что в рамках транзакции, будут выполнены либо все запросы, либо ни одного.**
#
#
# *   Атомарность гарантирует, что в при одновременном выполнении нескольких транзакций, они не будут влиять друг на друга.
# *    Атомарность гарантирует, что в случае успешного завершения транзакции, её нельзя будет отменить.
#
#
#
#
#
#
#
# # 5. Задание 5
# Выберите правильные определения согласованности (консистентности).
#
# Выберите все подходящие ответы из списка
#
#
#
# *   **Согласованность относится к бизнес-логике приложения, а не к конкретным SQL запросам**
# *   Согласованные транзакции нельзя отменить.
#
#
# *   **Согласованность отвечает за то, что в рамках транзакции фиксируются только допустимые результаты.**
# *    Согласованные транзакции — это транзакции, которые успешно завершились с помощью COMMIT.
# *    Согласованность гарантирует, что в рамках транзакции, будут выполнены либо все запросы, либо ни одного.
#
#
# # 6. Задание 6
# Выберите правильное определение изолированности.
#
# Выберите один вариант из списка
#
# *   Изолированность гарантирует, что в рамках транзакции, будут выполнены либо все запросы, либо ни одного.
# *   **Изолированность отвечает за то, что при одновременном выполнении нескольких транзакций, они не должны оказывать влияния друг на друга.**
#
#
# *  Изолированность означает, что SQL запросы в рамках одной транзакции не влияют друг на друга.
# *    Изолированность означает, что все SQL запросы в рамках одной транзакции выполняются атомарно.
#
#
# # 7. Задание 7
# Выберите правильное определение устойчивости к ошибкам (Durability).
#
# Выберите один вариант из списка
#
# *   Устойчивость гарантирует, что транзакция будет выполнена при любых данных пользователя.
# *   Устойчивость гарантирует, что при запуске транзакции, она в 100% будет выполнена.
#
#
# *  Устойчивость гарантирует, что в рамках транзакции будут выполнены либо все запросы, либо ни одного.
# *    **Устойчивость гарантирует, что если транзакция будет выполнена, то ничего её уже не отменит (ни выключенный сервер, ни сетевой сбой).**
#
# # 8. Задание 8
# Выберите свойство транзакции, которое наиболее точно описывает следующую формулировку:
# Транзакция — группа последовательных операций с базой данных, которая представляет собой логическую единицу работы с данными. Транзакция может быть выполнена либо целиком и успешно, либо не выполнена вообще, и тогда она не должна произвести никакого эффекта.
#
# Выберите один вариант из списка
#
# *   Устойчивость к ошибкам
# *   **Атомарность**
#
#
# *  Изолированность
# *    Согласованность
#
#
# # 9. Задание 9
# Выберите свойство транзакции, которое наиболее точно описывает следующую формулировку:
# Во время выполнения транзакции, параллельные транзакции не должны оказывать влияния на её результат.
#
# Выберите один вариант из списка
#
# *   Устойчивость к ошибкам
# *   Атомарность
#
#
# *  **Изолированность**
# *    Согласованность
#
# # 10. Задание 10
# Выберите определение, которое правильно описывает суть потерянного обновления:
#
# Выберите один вариант из списка
#
# *   Потерянное обновление возникает, когда транзакции выполняются в обратном порядке.
# *   **Потерянное обновление возникает, когда последняя транзакция перезаписывает данные первых транзакций.**
#
#
# *  Потерянное обновление возникает, когда первая транзакция блокирует выполнение остальных транзакций.
# *    Потерянное обновление возникает, когда ни одна из параллельных транзакций не выполняется.
#
# # 11. Задание 11
# Выберите верные утверждения:
#
# Выберите все подходящие ответы из списка
#
# *   **На уровне изоляции READ UNCOMMITED потерянные обновления, как правило, не возникают.**
# *   **При использовании чистых UPDATE-запросов на уровне READ UNCOMMITED потерянные обновления возникать не будут.**
#
#
# *  **На уровне изоляции READ UNCOMMITED потерянные обновления возникают, только если использовать промежуточные переменные.**
# *    Потерянные обновления всегда возникают на уровне изоляции READ UNCOMMITED.
#
#
# # 12. Задание 12
# Отметьте ситуацию, при которой возникает грязное чтение:
#
# Выберите один вариант из списка
#
# *   Одна из транзакций видит только часть данных в таблице.
# *   **Одна из транзакций читает незафиксированные данные, которые будут отменены (ROLLBACK) другой транзакцией.**
#
#
# *  Одна из транзакций читает зафиксированные (COMMT) данные, после успешного выполнения другой транзакции.
# *    Из-за сетевых ошибок, часть прочитанных данных теряется и транзакция видит «битую» информацию.
#
#
# # 13. Задание 13
# Выберите верные утверждения, которые описывают уровень изоляции READ COMMITTED:
#
# Выберите все подходящие ответы из списка
#
# *  Если какая-то из транзакций уже изменила часть данных, но еще не завершила работу.
# То на уровне READ COMMITTED другая транзакция видит измененные данные.
# *   **Если какая-то из транзакций уже изменила часть данных, но еще не завершила работу.
# То на уровне READ COMMITTED другая транзакция видит данные, до того как первая транзакция начала выполнение.**
#
#
# *   На уровне READ COMMITTED проблема потерянной транзакции исчезает, даже при использовании временных переменных.
# *    **При изоляции READ COMMITTED транзакция может прочитать только те данные, которые были зафиксированы с помощью COMMIT.**
# *    При изоляции READ COMMITTED транзакция может прочитать любые данные, даже те, которые не были зафиксированы с помощью COMMIT.
#
# # 14. Задание 14
# Выберите определение, которое наиболее точно описывает эффект неповторяющегося чтения:
#
# Выберите один вариант из списка
#
# *   Неповторяющееся чтение возникает, когда две транзакции получают разные данные из одной таблицы.
# *   Неповторяющееся чтение возникает, когда транзакция пытается дважды выполнить один и тот же SELECT запрос, но второй запрос не проходит и выполняется ROLLBACK.
#
#
# *  **Неповторяющееся чтение возникает, когда два одинаковых или почти одинаковых SQL запроса получают разные данные в рамках одной транзакции.**
# *    Неповторяющееся чтение возникает, когда транзакция не видит изменений, которые она же и внесла.
#
# # 15. Задание 15
# На каких уровнях изоляции транзакций эффект неповторяющегося чтения пропадает?
#
# Выберите все подходящие ответы из списка
#
# *   Read uncommitted
# *   **Repeatable read**
#
#
# *  **Serializable**
# *    Read committed
#
# # 16. Задание 16
# Выберите определения, которые верно характеризуют четвертый уровень изоляции транзакций.
#
# Выберите все подходящие ответы из списка
#
# *   Нужно всегда использовать только четвертый уровень изоляции транзакции.
# *   **На четвертом уровне изоляции исключаются любые проблемы параллельного выполнения транзакций.**
#
#
# *  На четвертом уровне изоляции транзакции выполняются параллельно.
# *    **На четвертом уровне изоляции транзакции выполняются последовательно.**
# *  **Четвертый уровень самый ресурсоемкий, его нужно использовать только в критических местах программ.**
# *    Четвертый уровень изоляции позволяет избавиться только от ошибки фантомного чтения.
#
# # 17. Задание 17
# Выберите случаи, в которых нужно использовать максимальный уровень изоляции.
#
# Выберите все подходящие ответы из списка
#
# *   **Медицинские приложения (фиксация данных пациентов, сохранение анализов, запись на приём).**
# *   **Система выборов президента (фиксация голосов избирателей).**
#
#
# *  **Система бронирования номеров в гостиницах.**
# *    Счетчик просмотров на новостном сайте
# *  **Банковские приложения (перевод денег, зачисление на счет, списания)..**
