# %% [markdown]
# # 1. Типы ссылок 1
# Выбери формулу, которая написана в ячейке C3
#
# Эту формулу можно скопировать вправо и вниз. Получатся данные, как в таблице.
#
# ![Типы ссылок (для 2).png](data:image/png;base64,...)
#
#
# Ответ:
#
#
# 1
#
# **2**
#
# 3
#
# 4
#
#
# # 2. Типы ссылок 2
# Как называется ссылка на ячейку ![$B$3.png](data:image/png;base64,...)
#
# Ответ:
#
# **Абсолютная**
#
# Относительная
#
# Смешанная
#
# Нет верного ответа
#
#
# # 3. Типы ссылок 3
# Выберите правильное написание формулы в C4 (распределение общего плана на регионы с учётом структуры продаж)
#
# ![1-1 ссылки.png](data:image/png;base64,...)
#
# Ответ:
#
# 1
#
# **2**
#
# 3
#
# 4
#
#
# # 4. Математические статистические формулы 1
# Сопоставьте следующие функции с их описанием
#
#
# Ответ:
#
# =СУММ()       Суммирует аргументы.
# =СУММЕСЛИ()   Суммирует ячейки, удовлетворяющие заданному условию.
# =СЧЁТ()       Подсчитывает количество ячеек, содержащих числа
# =СЧЁТЕСЛИ()   Подсчитывает количество ячеек, удовлетворяющих условию
#
#
# # 5. Математические статистические формулы 2
# Как подсчитать количество проданных мячей?
#
# ![image.png](data:image/png;base64,...)
#
# Ответ:
#
#
# =СУММЕСЛИ(A:A;"?мя?";B:B)
#
# =СУММЕСЛИ(A:A;"мяч";B:B)
#
# =СУММЕСЛИ(A:A;"мяч?";B:B)
#
# =СУММ(B:B)
#
# **=СУММЕСЛИ(A:A;"мяч*";B:B)**
#
# # 6. Математические стаистические формулы 3
# С помощью какой функции посчитана сумма продаж Лентяева А.
#
# ![image.png](data:image/png;base64,...)
#
# Ответ:
#
#
# **=СУММЕСЛИ(A:A;"Лентяев А.";B:B)**
#
# =СУММЕСЛИ(B:B;"Лентяев А.";A:A)
#
# =СУММКОГДА(A:A;"Лентяев А.";B:B)
#
# =СУММЕСЛИ(A:A;"Лентяев А.")
#
#
# # 7. Математические статистические формулы 4
# Введите результат вычисления формулы:
#
# =СУММЕСЛИ(B:B;">"&100%;D:D)
#
# ![image.png](data:image/png;base64,...)
#
# Ответ:
#
# 130000
#
# # 8. Формулы подстановки 1
# Какая формула написана в ячейке F3?
#
# ![image.png](data:image/png;base64,...)
#
# Ответ:
#
#
# **=ВПР(E3;B:C;2;ЛОЖЬ)**
#
# =ВПР(E3;C:C;2;ЛОЖЬ)
#
# =ВПР(E3;A:C;2;ЛОЖЬ)
#
# =ВПР(E3;A:C;3;ЛОЖЬ)
#
# # 9. Формулы подстановки 2
# Сопоставьте следующие функции ссылок и подстановки с их описанием:
#
# Ответ:
#
# =ИНДЕКС()      Использует индекс для выбора значения из ссылки или массива.
#
# =ПОИСКПОЗ()    Ищет значения в ссылке или массиве.
#
# =ВПР()         Выполняет поиск в первом столбце массива и возвращает  значение  указанной ячейки.
#
#
# # 10. Логические функции 1
# Вы решили "доплатить" сотрудникам 2 000 руб. Ниже результат вашей работы.
#
# ![image.png](data:image/png;base64,...)
#
# Какую формулу вы использовали?
#
# Ответ:
#
# **=ЕСЛИ(B2>80%;2000;0)**
#
# =ЕСЛИ(B2>80;2000;0)
#
# =ЕСЛИ(B2>=80%;2000;0)
#
# =ЕСЛИ(B2>80%;2000)
#
# # 11. Логические функции 2
# Вам нужно было начислить 1 000 руб, если семья многодетная.
#
# ![image.png](data:image/png;base64,...)
#
# Какую формулу вы использовали?
#
# Ответ:
#
#
# **=ЕСЛИ(B2>=3;1000;0)**
#
# =ЕСЛИ(B2<3;1000;0)
#
# =ЕСЛИ(B2<=3;1000;0)
#
# =ЕСЛИ(B2>3;1000;0)
#
#
# # 12. Логические функции 3
# По какой формуле в ячейке C2 можно рассчитать доплату 2-ой и 4-ой бригадам в размере 3 000 руб.
#
# ![image.png](data:image/png;base64,...)
#
# Ответ:
#
# =ИЛИ(ЕСЛИ(В2=2;В2=4);3000;0)
#
# =И(ЕСЛИ(В2=2;B2=4);3000;0)
#
# **=ЕСЛИ(ИЛИ(B2=2;B2=4);3000;0)**
#
# =ЕСЛИ(И(В2=2;В2=4);3000;0)
#
# # 13. Продвинутая работа с текстом 1
# Какой результат получим в ячейке А4?
#
# ![image.png](data:image/png;base64,...)
#
# Ответ:
#
#
# МСК
#
# **"700"**
#
# 700
#
# МСК;
#
# # 14. Продвинутая работа с текстом 2
# Какой результат получим в ячейке А4?
#
# ![image.png](data:image/png;base64,...)
#
#
# Ответ:
#
#
# **"МСК"**
#
# нет верного ответа
#
# "700"
#
# 700
#
# # 15. Продвинутая работа с текстом 3
# Выберите все варианты преобразования формулы =ПРАВСИМВ(A2;5) в числовое значение
#
# ![image.png](data:image/png;base64,...)
#
# Ответ:
#
#
# **=ПРАВСИМВ(A2;5)*1**
#
# =ПРАВСИМВ(A2;5)*100
#
# =ПРАВСИМВ(A2;5)+1
#
# **=ПРАВСИМВ(A2;5)/1**
#
# **=--ПРАВСИМВ(A2;5)**
#
# **=ПРАВСИМВ(A2;5)+0**
#
# # 16. Продвинутая сортировка 1
# Сортировать таблицу можно только по значению
#
# Ответ:
#
# Верно
#
# **Неверно**
#
#
# # 17. Продвинутая сортировка 2
# Составьте правильный порядок сортировки:
#
# Ответ:
#
# Выделить таблицу целиком
#
# Перейти на вкладку Данные
#
# Выбрать команду Сортировка
#
# Выбрать столбец/логику/порядок сортировки
#
# Нажать ОК
#
# # 18. Продвинутая сортировка 3
# Посмотрите на таблицу и расставьте слова по своим местам
#
# ![image.png](data:image/png;base64,...)
#
#
# Ответ:
#
# В таблице выполнена
# **Сортировка**
#  по столбцу
# **Уровень**
#  с типом
# **по цвету**
#
# # 19. Проверка вводимых значений 1
# Как называется элемент, обведенный красной рамкой
#
# ![image.png](data:image/png;base64,...)
#
# Ответ:
#
#
# ToolTips
#
# Информация
#
# Проверка данных
#
# **Подсказка по вводу**
#
# Это фотомонтаж
#
# # 20. Проверка вводимых значений 2
# Заполните пропуски
#
# Ответ:
#
# В Excel можно ограничивать ввод некорректных данных с помощью
# **проверка данных**
#  Для текстовых значений используйте тип проверки
# **Список**
#
#
# # 21. Защита данных 1
# В Excel можно защитить:
#
# Ответ:
#
#
# **Диапазон ячеек (без пароля/с паролем)**
#
# **Лист (без пароля/с паролем)**
#
# **Только одну ячейку**
#
# **Excel-файл**
#
# # 22. Защита данных 2
# Все ячейки на листе Excel файла по умолчанию являются ...
#
# Ответ:
#
#
# **защищаемыми**
#
# незащищаемыми
