# %% [markdown]
# # 1. Относительные ссылки
# Если выполнили задание на листе Относит.ссылки, то напишите сюда значение ячейки H12
#
# Пишите целое число (К примеру, если получилось 15650,56, то в ответе пишем 15650)
#
#
# Ответ:
#
# 255450
#
#
# # 2. Абсолютные ссылки 1
# Какая клавиша на клавиатуре позволяет менять тип ссылки?
#
# Ответ:
#
# Shift
#
# F1
#
# **F4**
#
# Alt
#
#
# # 3. Абсолютные ссылки 2
# Напиши сюда значение ячейки H12 листа Абсолют.ссылки
#
# Пишите целое число (К примеру, если получилось 5650,56, то в ответе пишем 5650)
#
# Ответ:
# ```
# 4040
# ```
#
# # 4. Математические и статистические формулы 1
# С помощью какой формулы можно найти сумму продаж конкретного сотрудника?
#
# Ответ:
#
# СЧЁТЕСЛИ
#
# СЧЁТ
#
# **СУММЕСЛИ**
#
# СУММАКОГДА
#
# СУММА
#
# # 5. Математические и статистические формулы 2
# Какая функция подсчитывает количество ячеек в списке аргументов, которые содержат только числовые значения?
#
# Ответ:
#
# **СЧЁТ/COUNT**
#
# СЧЁТЕСЛИ/COUNTIF
#
# СУММЕСЛИ/SUMIF
#
# СУММ/SUM
#
# # 6. Формула ВПР 1
# Вставь пропущенное слово: Функция ВПР (вертикальный просмотр) ищет значение в крайнем _________ столбце исследуемого диапазона, а затем возвращает результат из ячейки, которая находится на пересечении найденной строки и заданного столбца.
#
# Ответ:
#
# **левом**
#
# правом
#
#
# # 7. Формула ВПР 2
# Можно ли с помощью ВПР "подтягивать" значения из таблиц, которые находятся в других Excel файлах?
#
# Ответ:
#
# **Да, можно**
#
# Нет, нельзя
#
# # 8. Работа с текстом 1
# Результат работы формулы = ЛЕВСИМВ(A1;5) , если A1 = Якушев Дмитрий
#
# Ответ:
#
# трий
#
# Якушев
#
# Дмитрий
#
# **Якуше**
#
# # 9. Работа с текстом 2
# Результат работы формулы = СЦЕПИТЬ(A1;A2) , если A1 =Якушев, A2=Дмитрий
#
# Ответ:
#
# ДмитрийЯкушев
#
# Дмитрий Якушев
#
# **ЯкушевДмитрий**
#
# Якушев Дмитрий
#
# # 10. Работа с датами 1
# Какая функция возвращает порядковый номер даты, которая отстает от заданной на определенное количество рабочих дней вперед или назад.
#
# Ответ:
#
# **РАБДЕНЬ**
#
# МЕСЯЦ
#
# ДАТА
#
# ГОД
#
# # 11. Работа с датами 2
# Сколько обязательных аргументов у функции ДАТА() ?
#
# Ответ:
#
# 1
#
# 2
#
# **3**
#
# 4
#
#
# # 12. Сортировка и фильтрация 1
# Можно ли создать 3х уровневую сортировку в рамках одной таблицы?
#
# Ответ:
#
# **Да, можно**
#
# Нет, нельзя
#
# # 13. Сортировка и фильтрация 2
# Какой инструмент Excel позволяет отобразить среди большого объема информации только ту, что в данный момент необходима?
#
# Ответ:
#
# Сортировка
#
# **Фильтрация**
#
# # 14. Сводные таблицы 1
# Можно ли с помощью сводных таблиц узнать общую сумму продаж определенных товаров?
#
# Ответ:
#
# **Да, можно**
#
# Нет, нельзя
#
# # 15. Сводные таблицы 2
# Может ли сводная таблица ответить на вопрос: кто больше купил определенного товара в месяц женщины или мужчины?
#
# Ответ:
#
# **Да, может. Если информация по полу есть в исходных данных.**
#
# Да, может. Даже, если информация по полу нет в исходных данных.
#
# Нет, вне зависимости, если данные по полу или нет
#
# # 16. Условное форматирование 1
# Как называет вариант условного форматирования, предполагающий градиентную или сплошную заливку ячейки?
#
# Длина заливки напрямую зависит от числа, находящегося в ней.
#
# Ответ:
#
# Диаграмма
#
# **Гистограмма**
#
# Цветовая шкала
#
# Фильтр
#
#
# # 17. Условное форматирование 2
# Как называет вариант условного форматирования, предполагающий заливку в 2 или 3 цвета. Интенсивность цвета напрямую зависит от числа, находящегося в ячейке
#
# Ответ:
#
# Диаграмма
#
# **Цветовая шкала**
#
# Сортировка
#
# Гистограмма
